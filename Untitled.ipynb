# %% [markdown]
# # Automata project

# %%
# Conway cellular automata
import numpy as np
import time
from IPython.display import clear_output

def initialize_grid(height, width):
    return np.random.randint(2, size=(height, width), dtype=bool)

def get_neighbors_count(grid, x, y):
    height, width = grid.shape
    neighbors = [(x - 1, y - 1), (x - 1, y), (x - 1, y + 1),
                 (x, y - 1),                 (x, y + 1),
                 (x + 1, y - 1), (x + 1, y), (x + 1, y + 1)]

    count = 0
    for nx, ny in neighbors:
        count += grid[nx % height, ny % width]

    return count

def update_grid(grid):
    new_grid = np.copy(grid)
    height, width = grid.shape

    for x in range(height):
        for y in range(width):
            neighbors_count = get_neighbors_count(grid, x, y)

            if grid[x, y]:  # If the cell is alive
                if neighbors_count < 2 or neighbors_count > 3:
                    new_grid[x, y] = False  # Cell dies due to underpopulation or overpopulation
            else:
                if neighbors_count == 3:
                    new_grid[x, y] = True  # Cell becomes alive due to reproduction

    return new_grid

def print_grid(grid):
    clear_output(wait=True)
    for row in grid:
        print(''.join('X' if cell else ' ' for cell in row))
    time.sleep(0.1)

def main():
    height, width = 20, 40
    grid = initialize_grid(height, width)

    while True:
        print_grid(grid)
        grid = update_grid(grid)

if __name__ == "__main__":
    main()
# Out:
#                    XX   XX    XX
#                    XX   XX    XX
#
#
#         XX
#        X  X
#        X  X
#         XX            XX
#                      X  X
#                       XX    XXX
#                            XXX
#
#
#
#                                  X
#                                 X X
#                                X  X
#                                 XX
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 52
#      49         grid = update_grid(grid)
#      51 if __name__ == "__main__":
# ---> 52     main()
#
# Cell In[1], line 48, in main()
#      45 grid = initialize_grid(height, width)
#      47 while True:
# ---> 48     print_grid(grid)
#      49     grid = update_grid(grid)
#
# Cell In[1], line 41, in print_grid(grid)
#      39 for row in grid:
#      40     print(''.join('X' if cell else ' ' for cell in row))
# ---> 41 time.sleep(0.1)
#
# KeyboardInterrupt:

# %%
LOLLLL?????????? it works? bra

# %%
import pygame
import neat
import os

# Define the window dimensions
WINDOW_WIDTH = 800
WINDOW_HEIGHT = 600

# Define worm dimensions
WORM_WIDTH = 20
WORM_HEIGHT = 20

# Define colors
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Define the worm class
class Worm:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.vel_x = 0
        self.vel_y = 0

    def move(self):
        self.x += self.vel_x
        self.y += self.vel_y

# Initialize pygame
pygame.init()
window = pygame.display.set_mode((WINDOW_WIDTH, WINDOW_HEIGHT))
clock = pygame.time.Clock()

# Create the worm
worm = Worm(WINDOW_WIDTH // 2, WINDOW_HEIGHT // 2)

# NEAT setup
def run_neat(config_file):
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation, config_file)

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)

    winner = population.run(eval_genomes, 100)

    # Display the winning neural network
    net = neat.nn.FeedForwardNetwork.create(winner, config)
    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                return
        inputs = (worm.x, worm.y, WINDOW_WIDTH, WINDOW_HEIGHT)
        output = net.activate(inputs)
        worm.vel_x = output[0] * 5
        worm.vel_y = output[1] * 5
        worm.move()

        window.fill(WHITE)
        pygame.draw.rect(window, RED, (worm.x, worm.y, WORM_WIDTH, WORM_HEIGHT))
        pygame.display.update()
        clock.tick(60)

if __name__ == "__main__":
    local_dir = os.getcwd()
    config_path = os.path.join(local_dir, "config-feedforward-fast.txt")
    run_neat(config_path)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -11478.23503 stdev: 7558.89978
# Best fitness: 0.00000 - size: (2, 8) - species 1 - id 1
# Average adjusted fitness: 0.580
# Mean genetic distance 1.334, standard deviation 0.361
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   150      0.0    0.580     0
# Total extinctions: 0
# Generation time: 0.061 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -4539.35950 stdev: 7188.96869
# Best fitness: 0.00000 - size: (3, 8) - species 1 - id 151
# Average adjusted fitness: 0.817
# Mean genetic distance 1.387, standard deviation 0.350
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   150      0.0    0.817     1
# Total extinctions: 0
# Generation time: 0.065 sec (0.063 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -4014.58105 stdev: 6268.46022
# Best fitness: 0.00000 - size: (3, 9) - species 1 - id 301
# Average adjusted fitness: 0.821
# Mean genetic distance 1.518, standard deviation 0.351
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   150      0.0    0.821     2
# Total extinctions: 0
# Generation time: 0.064 sec (0.063 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -3351.77813 stdev: 6205.24931
# Best fitness: 0.00000 - size: (2, 8) - species 1 - id 452
# Average adjusted fitness: 0.835
# Mean genetic distance 1.649, standard deviation 0.371
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   150      0.0    0.835     3
# Total extinctions: 0
# Generation time: 0.069 sec (0.065 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -3580.14706 stdev: 6428.61133
# Best fitness: 0.00000 - size: (2, 6) - species 1 - id 602
# Average adjusted fitness: 0.811
# Mean genetic distance 1.715, standard deviation 0.374
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   150      0.0    0.811     4
# Total extinctions: 0
# Generation time: 0.067 sec (0.065 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -3108.92838 stdev: 6141.80097
# Best fitness: 0.00000 - size: (3, 7) - species 1 - id 753
# Average adjusted fitness: 0.836
# Mean genetic distance 1.808, standard deviation 0.402
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   150      0.0    0.836     5
# Total extinctions: 0
# Generation time: 0.066 sec (0.065 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -2682.20607 stdev: 5858.07105
# Best fitness: 0.00000 - size: (3, 8) - species 1 - id 902
# Average adjusted fitness: 0.880
# Mean genetic distance 1.731, standard deviation 0.395
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   150      0.0    0.880     6
# Total extinctions: 0
# Generation time: 0.065 sec (0.065 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -3011.12771 stdev: 6188.96163
# Best fitness: 0.00000 - size: (2, 6) - species 1 - id 1051
# Average adjusted fitness: 0.881
# Mean genetic distance 1.776, standard deviation 0.400
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   150      0.0    0.881     7
# Total extinctions: 0
# Generation time: 0.067 sec (0.066 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -2786.21808 stdev: 5731.13241
# Best fitness: 0.00000 - size: (5, 7) - species 1 - id 1201
# Average adjusted fitness: 0.853
# Mean genetic distance 1.731, standard deviation 0.381
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   150      0.0    0.853     8
# Total extinctions: 0
# Generation time: 0.067 sec (0.066 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -2721.13059 stdev: 5506.69642
# Best fitness: 0.00000 - size: (2, 2) - species 1 - id 1351
# Average adjusted fitness: 0.856
# Mean genetic distance 1.893, standard deviation 0.430
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   110      0.0    0.856     9
#      2    0    40       --       --     0
# Total extinctions: 0
# Generation time: 0.064 sec (0.066 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -3229.00837 stdev: 6018.69296
# Best fitness: 0.00000 - size: (4, 6) - species 2 - id 1501
# Average adjusted fitness: 0.813
# Mean genetic distance 2.119, standard deviation 0.481
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10   130      0.0    0.848    10
#      2    1    20      0.0    0.777     0
# Total extinctions: 0
# Generation time: 0.066 sec (0.066 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -3313.54054 stdev: 6241.43047
# Best fitness: 0.00000 - size: (5, 10) - species 1 - id 1651
# Average adjusted fitness: 0.878
# Mean genetic distance 2.047, standard deviation 0.624
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11   105      0.0    0.806    11
#      2    2    45      0.0    0.950     1
# Total extinctions: 0
# Generation time: 0.072 sec (0.067 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -4616.26329 stdev: 7633.13878
# Best fitness: 0.00000 - size: (2, 5) - species 1 - id 1802
# Average adjusted fitness: 0.854
# Mean genetic distance 2.067, standard deviation 0.570
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    95      0.0    0.837    12
#      2    3    55      0.0    0.871     2
# Total extinctions: 0
# Generation time: 0.064 sec (0.067 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -3371.27170 stdev: 6259.03281
# Best fitness: 0.00000 - size: (3, 6) - species 1 - id 1952
# Average adjusted fitness: 0.842
# Mean genetic distance 2.102, standard deviation 0.539
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    87      0.0    0.767    13
#      2    4    63      0.0    0.916     3
# Total extinctions: 0
# Generation time: 0.059 sec (0.066 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -3146.72885 stdev: 5810.03855
# Best fitness: 0.00000 - size: (3, 5) - species 1 - id 2103
# Average adjusted fitness: 0.835
# Mean genetic distance 2.161, standard deviation 0.513
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    92      0.0    0.870    14
#      2    5    58      0.0    0.800     4
# Total extinctions: 0
# Generation time: 0.059 sec (0.065 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -2826.57210 stdev: 5834.08676
# Best fitness: 0.00000 - size: (3, 1) - species 1 - id 2252
# Average adjusted fitness: 0.850
# Mean genetic distance 2.300, standard deviation 0.500
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    70      0.0    0.853    15
#      2    6    75      0.0    0.847     5
#      3    0     5       --       --     0
# Total extinctions: 0
# Generation time: 0.059 sec (0.064 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -1617.64216 stdev: 4517.91109
# Best fitness: 0.00000 - size: (2, 0) - species 2 - id 2402
# Average adjusted fitness: 0.940
# Mean genetic distance 2.573, standard deviation 0.602
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    44      0.0    0.884    16
#      2    7    41      0.0    0.937     6
#      3    1    56      0.0    1.000     0
#      4    0     8       --       --     0
# Total extinctions: 0
# Generation time: 0.056 sec (0.063 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -3423.67545 stdev: 6153.55581
# Best fitness: 0.00000 - size: (2, 1) - species 3 - id 2551
# Average adjusted fitness: 0.902
# Mean genetic distance 2.652, standard deviation 0.568
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    38      0.0    0.899    17
#      2    8    20      0.0    0.946     7
#      3    2    20      0.0    0.764     1
#      4    1    72      0.0    1.000     0
# Total extinctions: 0
# Generation time: 0.053 sec (0.062 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -1701.78128 stdev: 4386.77929
# Best fitness: 0.00000 - size: (2, 2) - species 1 - id 2700
# Average adjusted fitness: 0.892
# Mean genetic distance 2.650, standard deviation 0.707
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    45      0.0    0.901    18
#      2    9    23      0.0    0.843     8
#      3    3    24      0.0    0.922     2
#      4    2    57      0.0    0.904     1
# Total extinctions: 0
# Generation time: 0.050 sec (0.060 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -3311.16119 stdev: 6085.56996
# Best fitness: 0.00000 - size: (2, 1) - species 2 - id 2850
# Average adjusted fitness: 0.822
# Mean genetic distance 2.656, standard deviation 0.687
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    51      0.0    0.757    19
#      2   10    31      0.0    0.766     9
#      3    4    16      0.0    0.890     3
#      4    3    50      0.0    0.875     2
#      5    0     1       --       --     0
# Total extinctions: 0
# Generation time: 0.052 sec (0.059 average)
#
#  ****** Running generation 20 ******
# Population's average fitness: -3517.95745 stdev: 6218.97656
# Best fitness: 0.00000 - size: (2, 2) - species 1 - id 2999
#
# Species 1 with 51 members is stagnated: removing it
# Average adjusted fitness: 0.859
# Mean genetic distance 2.663, standard deviation 0.789
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2
average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -1341.69275 stdev: 4039.38050
# Best fitness: 0.00000 - size: (3, 2) - species 5 - id 4947
# Average adjusted fitness: 0.908
# Mean genetic distance 2.497, standard deviation 0.812
# Population of 151 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   18    14      0.0    0.799    17
#      4   17    46      0.0    0.932    16
#      5   14    11      0.0    1.000    12
#      6   13    27      0.0    0.952    12
#      7    7    22      0.0    1.000     6
#      8    7    15      0.0    0.873     6
#      9    7    16      0.0    0.802     6
# Total extinctions: 0
# Generation time: 0.045 sec (0.047 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -1476.20452 stdev: 4434.06261
# Best fitness: 0.00000 - size: (3, 2) - species 5 - id 5098
# Average adjusted fitness: 0.907
# Mean genetic distance 2.578, standard deviation 0.843
# Population of 151 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   19    13      0.0    0.817    18
#      4   18    48      0.0    0.945    17
#      5   15     7      0.0    1.000    13
#      6   14    28      0.0    0.869    13
#      7    8    33      0.0    0.955     7
#      8    8    12      0.0    0.925     7
#      9    8    10      0.0    0.841     7
# Total extinctions: 0
# Generation time: 0.044 sec (0.047 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -1985.29665 stdev: 4989.12241
# Best fitness: 0.00000 - size: (3, 1) - species 4 - id 5249
# Average adjusted fitness: 0.858
# Mean genetic distance 2.603, standard deviation 0.818
# Population of 150 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   20    17      0.0    0.901    19
#      4   19    44      0.0    0.921    18
#      5   16    16      0.0    1.000    14
#      6   15    22      0.0    0.843    14
#      7    9    31      0.0    1.000     8
#      8    9    12      0.0    0.760     8
#      9    9     8      0.0    0.580     8
# Total extinctions: 0
# Generation time: 0.044 sec (0.046 average)
#
#  ****** Running generation 36 ******
# Population's average fitness: -948.76694 stdev: 3450.89580
# Best fitness: 0.00000 - size: (3, 1) - species 4 - id 5400
#
# Species 3 with 17 members is stagnated: removing it
# Average adjusted fitness: 0.922
# Mean genetic distance 2.502, standard deviation 0.786
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   20    33      0.0    0.987    19
#      5   17    18      0.0    0.865    15
#      6   16    31      0.0    0.954    15
#      7   10    44      0.0    0.963     9
#      8   10     5      0.0    0.833     9
#      9   10    19      0.0    0.929     9
# Total extinctions: 0
# Generation time: 0.050 sec (0.047 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -1320.57685 stdev: 4203.14796
# Best fitness: 0.00000 - size: (4, 3) - species 5 - id 5550
#
# Species 4 with 33 members is stagnated: removing it
# Average adjusted fitness: 0.896
# Mean genetic distance 2.523, standard deviation 0.794
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   18    20      0.0    0.844    16
#      6   17    27      0.0    0.867    16
#      7   11    58      0.0    0.953    10
#      8   11    22      0.0    0.886    10
#      9   11    23      0.0    0.929    10
# Total extinctions: 0
# Generation time: 0.049 sec (0.047 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -2081.79452 stdev: 4969.17953
# Best fitness: 0.00000 - size: (4, 3) - species 5 - id 5700
# Average adjusted fitness: 0.874
# Mean genetic distance 2.535, standard deviation 0.720
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   19    31      0.0    1.000    17
#      6   18    50      0.0    0.963    17
#      7   12    20      0.0    0.875    11
#      8   12    28      0.0    0.734    11
#      9   12    17      0.0    0.796    11
#     10    0     4       --       --     0
# Total extinctions: 0
# Generation time: 0.049 sec (0.047 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -2138.39695 stdev: 4916.77897
# Best fitness: 0.00000 - size: (4, 3) - species 5 - id 5850
# Average adjusted fitness: 0.897
# Mean genetic distance 2.631, standard deviation 0.714
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   20    31      0.0    0.972    18
#      6   19    35      0.0    0.910    18
#      7   13    33      0.0    0.856    12
#      8   13    18      0.0    0.761    12
#      9   13    18      0.0    0.882    12
#     10    1    16      0.0    1.000     0
# Total extinctions: 0
# Generation time: 0.050 sec (0.047 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -1316.08074 stdev: 4291.24578
# Best fitness: 0.00000 - size: (2, 0) - species 5 - id 6001
# Average adjusted fitness: 0.939
# Mean genetic distance 2.614, standard deviation 0.662
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   21    25      0.0    0.920    19
#      6   20    21      0.0    0.979    19
#      7   14    49      0.0    0.930    13
#      8   14    21      0.0    0.948    13
#      9   14    14      0.0    0.933    13
#     10    2    21      0.0    0.927     1
# Total extinctions: 0
# Generation time: 0.053 sec (0.048 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -1260.40929 stdev: 4091.49747
# Best fitness: 0.00000 - size: (3, 2) - species 5 - id 6151
#
# Species 5 with 25 members is stagnated: removing it
#
# Species 6 with 21 members is stagnated: removing it
# Average adjusted fitness: 0.940
# Mean genetic distance 2.437, standard deviation 0.677
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   15    71      0.0    0.921    14
#      8   15    23      0.0    0.928    14
#      9   15    15      0.0    0.961    14
#     10    3    41      0.0    0.948     2
# Total extinctions: 0
# Generation time: 0.050 sec (0.048 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: -1027.03333 stdev: 3767.80276
# Best fitness: 0.00000 - size: (3, 0) - species 7 - id 6302
# Average adjusted fitness: 0.941
# Mean genetic distance 2.415, standard deviation 0.704
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   16    87      0.0    0.958    15
#      8   16    21      0.0    1.000    15
#      9   16    11      0.0    0.933    15
#     10    4    31      0.0    0.871     3
# Total extinctions: 0
# Generation time: 0.046 sec (0.048 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: -1941.82341 stdev: 4659.78790
# Best fitness: 0.00000 - size: (2, 0) - species 7 - id 6452
# Average adjusted fitness: 0.868
# Mean genetic distance 2.493, standard deviation 0.794
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   17    77      0.0    0.923    16
#      8   17    17      0.0    0.864    16
#      9   17    30      0.0    0.909    16
#     10    5    16      0.0    0.775     4
#     11    0     9       --       --     0
# Total extinctions: 0
# Generation time: 0.050 sec (0.049 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: -1042.85122 stdev: 3437.26792
# Best fitness: 0.00000 - size: (2, 0) - species 7 - id 6602
# Average adjusted fitness: 0.910
# Mean genetic distance 2.436, standard deviation 0.778
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   18    67      0.0    0.967    17
#      8   18    14      0.0    0.866    17
#      9   18    11      0.0    0.948    17
#     10    6     7      0.0    0.879     5
#     11    1    50      0.0    0.889     0
# Total extinctions: 0
# Generation time: 0.061 sec (0.050 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: -1261.56833 stdev: 3890.36943
# Best fitness: 0.00000 - size: (2, 1) - species 11 - id 6751
# Average adjusted fitness: 0.904
# Mean genetic distance 2.293, standard deviation 0.743
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   19    66      0.0    0.932    18
#      8   19    14      0.0    0.711    18
#      9   19    10      0.0    1.000    18
#     10    7    13      0.0    0.919     6
#     11    2    47      0.0    0.957     1
# Total extinctions: 0
# Generation time: 0.059 sec (0.052 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: -929.16422 stdev: 3484.66885
# Best fitness: 0.00000 - size: (4, 2) - species 7 - id 6901
# Average adjusted fitness: 0.929
# Mean genetic distance 2.234, standard deviation 0.738
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   20    60      0.0    0.966    19
#      8   20    14      0.0    0.766    19
#      9   20    16      0.0    1.000    19
#     10    8    20      0.0    0.935     7
#     11    3    40      0.0    0.979     2
# Total extinctions: 0
# Generation time: 0.055 sec (0.052 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: -811.46266 stdev: 3078.15823
# Best fitness: 0.00000 - size: (2, 0) - species 7 - id 7050
#
# Species 7 with 60 members is stagnated: removing it
#
# Species 8 with 14 members is stagnated: removing it
#
# Species 9 with 16 members is stagnated: removing it
# Average adjusted fitness: 0.987
# Mean genetic distance 1.881, standard deviation 0.556
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10    9    79      0.0    1.000     8
#     11    4    71      0.0    0.975     3
# Total extinctions: 0
# Generation time: 0.047 sec (0.052 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: -949.47717 stdev: 3477.96280
# Best fitness: 0.00000 - size: (2, 1) - species 11 - id 7200
# Average adjusted fitness: 0.944
# Mean genetic distance 1.946, standard deviation 0.535
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   10    76      0.0    0.928     9
#     11    5    73      0.0    0.960     4
#     12    0     1       --       --     0
# Total extinctions: 0
# Generation time: 0.045 sec (0.052 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: -1155.41468 stdev: 3896.88109
# Best fitness: 0.00000 - size: (2, 1) - species 10 - id 7350
# Average adjusted fitness: 0.771
# Mean genetic distance 2.178, standard deviation 0.565
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   11    45      0.0    0.919    10
#     11    6    84      0.0    0.952     5
#     12    1    21  -9455.0    0.442     0
# Total extinctions: 0
# Generation time: 0.042 sec (0.051 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: -1383.22515 stdev: 3776.49621
# Best fitness: 0.00000 - size: (3, 2) - species 12 - id 7500
# Average adjusted fitness: 0.884
# Mean genetic distance 2.224, standard deviation 0.553
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   12    43      0.0    0.891    11
#     11    7    83      0.0    0.959     6
#     12    2    24      0.0    0.803     0
# Total extinctions: 0
# Generation time: 0.040 sec (0.050 average)
#
#  ****** Running generation 51 ******
# Population's average fitness: -1177.00836 stdev: 3826.18675
# Best fitness: 0.00000 - size: (4, 4) - species 12 - id 7650
# Average adjusted fitness: 0.924
# Mean genetic distance 2.297, standard deviation 0.490
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   13    51      0.0    0.943    12
#     11    8    82      0.0    0.938     7
#     12    3    17      0.0    0.891     1
# Total extinctions: 0
# Generation time: 0.042 sec (0.049 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: -621.73859 stdev: 2706.91400
# Best fitness: 0.00000 - size: (8, 5) - species 11 - id 7800
# Average adjusted fitness: 0.944
# Mean genetic distance 2.304, standard deviation 0.478
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   14   104      0.0    0.950    13
#     11    9    10      0.0    0.984     8
#     12    4    35      0.0    0.900     2
# Total extinctions: 0
# Generation time: 0.045 sec (0.049 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: -1304.86473 stdev: 3924.05772
# Best fitness: 0.00000 - size: (4, 5) - species 12 - id 7950
# Average adjusted fitness: 0.874
# Mean genetic distance 2.371, standard deviation 0.508
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   15    22      0.0    0.960    14
#     11   10   103      0.0    0.829     9
#     12    5    25      0.0    0.833     3
# Total extinctions: 0
# Generation time: 0.043 sec (0.048 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: -1469.52914 stdev: 4155.48468
# Best fitness: 0.00000 - size: (2, 1) - species 11 - id 8099
# Average adjusted fitness: 0.921
# Mean genetic distance 2.329, standard deviation 0.501
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   16    25      0.0    0.903    15
#     11   11   101      0.0    0.902    10
#     12    6    24      0.0    0.960     4
# Total extinctions: 0
# Generation time: 0.047 sec (0.047 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: -485.92733 stdev: 2466.08078
# Best fitness: 0.00000 - size: (9, 5) - species 11 - id 8249
# Average adjusted fitness: 0.969
# Mean genetic distance 2.394, standard deviation 0.569
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   17    26      0.0    0.960    16
#     11   12    58      0.0    0.972    11
#     12    7    24      0.0    0.976     5
#     13    0    42       --       --     0
# Total extinctions: 0
# Generation time: 0.045 sec (0.045 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: -780.92095 stdev: 2779.55495
# Best fitness: 0.00000 - size: (4, 3) - species 12 - id 8399
# Average adjusted fitness: 0.955
# Mean genetic distance 2.419, standard deviation 0.591
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   18    38      0.0    1.000    17
#     11   13    32      0.0    0.935    12
#     12    8    75      0.0    0.911     6
#     13    1     5      0.0    0.973     0
# Total extinctions: 0
# Generation time: 0.045 sec (0.044 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: -599.60008 stdev: 2625.39622
# Best fitness: 0.00000 - size: (3, 2) - species 12 - id 8549
# Average adjusted fitness: 0.876
# Mean genetic distance 2.424, standard deviation 0.700
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   19    38      0.0    0.985    18
#     11   14    11      0.0    0.969    13
#     12    9    13      0.0    0.977     7
#     13    2    88      0.0    0.572     1
# Total extinctions: 0
# Generation time: 0.045 sec (0.044 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: -805.63334 stdev: 3305.41118
# Best fitness: 0.00000 - size: (2, 0) - species 13 - id 8699
# Average adjusted fitness: 0.944
# Mean genetic distance 2.271, standard deviation 0.741
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   20    37      0.0    0.974    19
#     11   15    18      0.0    0.857    14
#     12   10    16      0.0    1.000     8
#     13    3    80      0.0    0.946     2
# Total extinctions: 0
# Generation time: 0.042 sec (0.044 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: -1387.48052 stdev: 4307.25429
# Best fitness: 0.00000 - size: (3, 1) - species 12 - id 8849
#
# Species 10 with 37 members is stagnated: removing it
# Average adjusted fitness: 0.921
# Mean genetic distance 2.195, standard deviation 0.684
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   16    22      0.0    0.957    15
#     12   11    29      0.0    0.902     9
#     13    4    76      0.0    0.904     3
#     14    0    19       --       --     0
#     15    0     4       --       --     0
# Total extinctions: 0
# Generation time: 0.042 sec (0.044 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: -1284.38365 stdev: 3957.45758
# Best fitness: 0.00000 - size: (4, 1) - species 12 - id 9000
# Average adjusted fitness: 0.914
# Mean genetic distance 2.560, standard deviation 0.748
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   17    24      0.0    0.853    16
#     12   12    19      0.0    0.889    10
#     13    5    67      0.0    0.988     4
#     14    1    29      0.0    0.838     0
#     15    1    11      0.0    1.000     0
# Total extinctions: 0
# Generation time: 0.043 sec (0.044 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: -1155.52035 stdev: 3773.85331
# Best fitness: 0.00000 - size: (3, 1) - species 13 - id 9150
# Average adjusted fitness: 0.897
# Mean genetic distance 2.554, standard deviation 0.842
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   18    14      0.0    0.934    17
#     12   13    55      0.0    0.970    11
#     13    6    44      0.0    0.992     5
#     14    2    22      0.0    0.823     1
#     15    2    15      0.0    0.766     1
# Total extinctions: 0
# Generation time: 0.044 sec (0.044 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: -1109.53718 stdev: 3918.26861
# Best fitness: 0.00000 - size: (5, 3) - species 12 - id 9300
# Average adjusted fitness: 0.936
# Mean genetic distance 2.479, standard deviation 0.759
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   19     8      0.0    0.935    18
#     12   14    63      0.0    0.948    12
#     13    7    37      0.0    0.990     6
#     14    3    20      0.0    0.863     2
#     15    3    23      0.0    0.946     2
# Total extinctions: 0
# Generation time: 0.044 sec (0.044 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: -910.13650 stdev: 3533.46590
# Best fitness: 0.00000 - size: (4, 2) - species 12 - id 9450
# Average adjusted fitness: 0.956
# Mean genetic distance 2.587, standard deviation 0.784
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   20    17      0.0    1.000    19
#     12   15    57      0.0    0.959    13
#     13    8    31      0.0    0.876     7
#     14    4    26      0.0    0.943     3
#     15    4    14      0.0    1.000     3
#     16    0     6       --       --     0
# Total extinctions: 0
# Generation time: 0.044 sec (0.044 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: -721.57416 stdev: 2804.93744
# Best fitness: 0.00000 - size: (5, 2) - species 12 - id 9601
#
# Species 11 with 17 members is stagnated: removing it
# Average adjusted fitness: 0.974
# Mean genetic distance 2.577, standard deviation 0.804
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     12   16    40      0.0    0.960    14
#     13    9    37      0.0    0.949     8
#     14    5    33      0.0    1.000     4
#     15    5    23      0.0    0.959     4
#     16    1    17      0.0    1.000     0
# Total extinctions: 0
# Generation time: 0.043 sec (0.044 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: -1245.78527 stdev: 3646.79499
# Best fitness: 0.00000 - size: (2, 1) - species 14 - id 9752
# Average adjusted fitness: 0.917
# Mean genetic distance 2.574, standard deviation 0.784
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     12   17    33      0.0    0.985    15
#     13   10    39      0.0    0.958     9
#     14    6    27      0.0    0.854     5
#     15    6    23      0.0    0.882     5
#     16    2    27      0.0    0.908     1
# Total extinctions: 0
# Generation time: 0.043 sec (0.044 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: -1799.88983 stdev: 4845.07121
# Best fitness: 0.00000 - size: (2, 0) - species 16 - id 9902
# Average adjusted fitness: 0.917
# Mean genetic distance 2.627, standard deviation 0.786
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     12   18    15      0.0    0.966    16
#     13   11    59      0.0    0.950    10
#     14    7    45      0.0    0.818     6
#     15    7    13      0.0    0.919     6
#     16    3    17      0.0    0.933     2
# Total extinctions: 0
# Generation time: 0.043 sec (0.043 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: -1637.52407 stdev: 4469.00806
# Best fitness: 0.00000 - size: (2, 0) - species 13 - id 10051
# Average adjusted fitness: 0.904
# Mean genetic distance 2.537, standard deviation 0.828
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     12   19    13      0.0    0.962    17
#     13   12    63      0.0    0.935    11
#     14    8    28      0.0    0.851     7
#     15    8    27      0.0    0.923     7
#     16    4    13      0.0    0.849     3
#     17    0     6       --       --     0
# Total extinctions: 0
# Generation time: 0.043 sec (0.043 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: -1229.68546 stdev: 3941.92077
# Best fitness: 0.00000 - size: (2, 0) - species 13 - id 10200
# Average adjusted fitness: 0.911
# Mean genetic distance 2.564, standard deviation 0.881
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     12   20    20      0.0    1.000    18
#     13   13    50      0.0    0.959    12
#     14    9    24      0.0    0.888     8
#     15    9    22      0.0    0.878     8
#     16    5     9      0.0    0.919     4
#     17    1    25      0.0    0.823     0
# Total extinctions: 0
# Generation time: 0.043 sec (0.043 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: -1744.04111 stdev: 4756.90006
# Best fitness: 0.00000 - size: (2, 0) - species 12 - id 10350
# Average adjusted fitness: 0.866
# Mean genetic distance 2.489, standard deviation 0.873
# Population of 149 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     12   21    21      0.0    0.956    19
#     13   14    50      0.0    1.000    13
#     14   10    23      0.0    0.922     9
#     15   10    29      0.0    0.915     9
#     16    6    16      0.0    0.646     5
#     17    2    10      0.0    0.760     1
# Total extinctions: 0
# Generation time: 0.042 sec (0.043 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: -1174.93939 stdev: 3807.44431
# Best fitness: 0.00000 - size: (2, 0) - species 12 - id 10500
#
# Species 12 with 21 members is stagnated: removing it
# Average adjusted fitness: 0.910
# Mean genetic distance 2.561, standard deviation 0.734
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   15    42      0.0    0.977    14
#     14   11    26      0.0    0.864    10
#     15   11    39      0.0    0.926    10
#     16    7    23      0.0    0.938     6
#     17    3    20      0.0    0.843     2
# Total extinctions: 0
# Generation time: 0.063 sec (0.045 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: -1752.25914 stdev: 4669.16734
# Best fitness: 0.00000 - size: (3, 0) - species 13 - id 10649
# Average adjusted fitness: 0.895
# Mean genetic distance 2.465, standard deviation 0.662
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   16     8      0.0    0.988    15
#     14   12   109      0.0    0.870    11
#     15   12     4      0.0    0.907    11
#     16    8    18      0.0    0.804     7
#     17    4    12      0.0    0.906     3
# Total extinctions: 0
# Generation time: 0.044 sec (0.045 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: -1424.43466 stdev: 3918.08029
# Best fitness: 0.00000 - size: (5, 2) - species 14 - id 10799
# Average adjusted fitness: 0.873
# Mean genetic distance 2.241, standard deviation 0.760
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   17    24      0.0    0.929    16
#     14   13    89      0.0    0.926    12
#     15   13    12      0.0    0.715    12
#     16    9    10      0.0    0.889     8
#     17    5    15      0.0    0.905     4
# Total extinctions: 0
# Generation time: 0.043 sec (0.045 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: -1038.89276 stdev: 3494.26345
# Best fitness: 0.00000 - size: (2, 0) - species 14 - id 10950
# Average adjusted fitness: 0.942
# Mean genetic distance 2.336, standard deviation 0.842
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   18    28      0.0    0.979    17
#     14   14    77      0.0    0.945    13
#     15   14    12      0.0    0.958    13
#     16   10    13      0.0    0.950     9
#     17    6    20      0.0    0.875     5
# Total extinctions: 0
# Generation time: 0.042 sec (0.045 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: -1578.22962 stdev: 4465.42757
# Best fitness: 0.00000 - size: (3, 0) - species 13 - id 11100
# Average adjusted fitness: 0.899
# Mean genetic distance 2.387, standard deviation 0.804
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   19    24      0.0    1.000    18
#     14   15    67      0.0    0.927    14
#     15   15    21      0.0    0.875    14
#     16   11    13      0.0    0.894    10
#     17    7    25      0.0    0.800     6
# Total extinctions: 0
# Generation time: 0.041 sec (0.045 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: -1263.79999 stdev: 4084.61481
# Best fitness: 0.00000 - size: (3, 0) - species 14 - id 11250
# Average adjusted fitness: 0.910
# Mean genetic distance 2.437, standard deviation 0.769
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   20    24      0.0    0.869    19
#     14   16    69      0.0    0.947    15
#     15   16    21      0.0    1.000    15
#     16   12    28      0.0    0.835    11
#     17    8     7      0.0    0.897     7
# Total extinctions: 0
# Generation time: 0.042 sec (0.045 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: -1428.35531 stdev: 3894.09778
# Best fitness: 0.00000 - size: (4, 3) - species 13 - id 11400
#
# Species 13 with 24 members is stagnated: removing it
# Average adjusted fitness: 0.891
# Mean genetic distance 2.309, standard deviation 0.685
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     14   17    87      0.0    0.951    16
#     15   17    24      0.0    0.872    16
#     16   13    25      0.0    0.890    12
#     17    9    15      0.0    0.853     8
# Total extinctions: 0
# Generation time: 0.043 sec (0.045 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: -2207.12399 stdev: 4857.94193
# Best fitness: 0.00000 - size: (2, 0) - species 14 - id 11549
# Average adjusted fitness: 0.839
# Mean genetic distance 2.307, standard deviation 0.668
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     14   18   111      0.0    0.895    17
#     15   18    23      0.0    0.942    17
#     16   14     4      0.0    0.766    13
#     17   10    13      0.0    0.753     9
# Total extinctions: 0
# Generation time: 0.043 sec (0.045 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: -2217.47244 stdev: 5304.40979
# Best fitness: 0.00000 - size: (2, 1) - species 14 - id 11700
# Average adjusted fitness: 0.766
# Mean genetic distance 2.302, standard deviation 0.616
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     14   19    91      0.0    0.916    18
#     15   19    21      0.0    0.878    18
#     16   15    12      0.0    0.561    14
#     17   11    26      0.0    0.711    10
# Total extinctions: 0
# Generation time: 0.044 sec (0.045 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: -1971.23541 stdev: 4952.44665
# Best fitness: 0.00000 - size: (4, 1) - species 14 - id 11851
# Average adjusted fitness: 0.902
# Mean genetic distance 2.270, standard deviation 0.626
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     14   20   104      0.0    0.913    19
#     15   20    15      0.0    0.899    19
#     16   16    24      0.0    0.961    15
#     17   12     6      0.0    0.837    11
# Total extinctions: 0
# Generation time: 0.044 sec (0.045 average)
#
#  ****** Running generation 80 ******
#
# Population's average fitness: -1543.96362 stdev: 4577.23364
# Best fitness: 0.00000 - size: (5, 5) - species 14 - id 12001
#
# Species 14 with 104 members is stagnated: removing it
#
# Species 15 with 15 members is stagnated: removing it
# Average adjusted fitness: 0.880
# Mean genetic distance 2.099, standard deviation 0.747
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   17    49      0.0    0.927    16
#     17   13    54      0.0    0.833    12
#     18    0    22       --       --     0
#     19    0    25       --       --     0
# Total extinctions: 0
# Generation time: 0.040 sec (0.043 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: -3819.87720 stdev: 6119.96949
# Best fitness: 0.00000 - size: (3, 1) - species 18 - id 12151
# Average adjusted fitness: 0.803
# Mean genetic distance 2.442, standard deviation 0.733
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   18    51      0.0    0.804    17
#     17   14    46      0.0    0.773    13
#     18    1    14      0.0    0.771     0
#     19    1    35      0.0    0.865     0
#     20    0     4       --       --     0
# Total extinctions: 0
# Generation time: 0.044 sec (0.043 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: -2672.85642 stdev: 5600.52182
# Best fitness: 0.00000 - size: (3, 0) - species 19 - id 12300
# Average adjusted fitness: 0.850
# Mean genetic distance 2.572, standard deviation 0.765
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   19    51      0.0    0.902    18
#     17   15    25      0.0    0.787    14
#     18    2    26      0.0    0.902     1
#     19    2    26      0.0    0.882     1
#     20    1    22      0.0    0.777     0
# Total extinctions: 0
# Generation time: 0.045 sec (0.043 average)
#
#  ****** Running generation 83 ******
# Population's average fitness: -2539.84134 stdev: 5734.01823
# Best fitness: 0.00000 - size: (3, 5) - species 16 - id 12450
# Average adjusted fitness: 0.876
# Mean genetic distance 2.570, standard deviation 0.635
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   20    48      0.0    0.802    19
#     17   16    25      0.0    0.835    15
#     18    3    44      0.0    0.947     2
#     19    3    16      0.0    1.000     2
#     20    2    17      0.0    0.794     1
# Total extinctions: 0
# Generation time: 0.045 sec (0.043 average)
#
#  ****** Running generation 84 ******
#
# Population's average fitness: -1965.40224 stdev: 4865.89429
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 12601
#
# Species 16 with 48 members is stagnated: removing it
# Average adjusted fitness: 0.925
# Mean genetic distance 2.367, standard deviation 0.729
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     17   17     8      0.0    0.914    16
#     18    4   110      0.0    0.938     3
#     19    4    11      0.0    0.938     3
#     20    3    21      0.0    0.908     2
# Total extinctions: 0
# Generation time: 0.041 sec (0.043 average)
#
#  ****** Running generation 85 ******
#
# Population's average fitness: -1269.06444 stdev: 3871.99326
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 12750
# Average adjusted fitness: 0.917
# Mean genetic distance 2.230, standard deviation 0.761
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     17   18    13      0.0    0.858    17
#     18    5    79      0.0    0.929     4
#     19    5    33      0.0    1.000     4
#     20    4    26      0.0    0.882     3
# Total extinctions: 0
# Generation time: 0.040 sec (0.043 average)
#
#  ****** Running generation 86 ******
#
# Population's average fitness: -1243.78859 stdev: 4024.94490
# Best fitness: 0.00000 - size: (2, 2) - species 17 - id 12900
# Average adjusted fitness: 0.924
# Mean genetic distance 2.298, standard deviation 0.720
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     17   19    27      0.0    0.883    18
#     18    6    70      0.0    0.950     5
#     19    6    26      0.0    0.950     5
#     20    5    28      0.0    0.913     4
# Total extinctions: 0
# Generation time: 0.042 sec (0.043 average)
#
#  ****** Running generation 87 ******
#
# Population's average fitness: -1821.24305 stdev: 4996.82904
# Best fitness: 0.00000 - size: (2, 1) - species 17 - id 13051
# Average adjusted fitness: 0.901
# Mean genetic distance 2.264, standard deviation 0.796
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     17   20    29      0.0    0.909    19
#     18    7    53      0.0    0.915     6
#     19    7    28      0.0    0.881     6
#     20    6    40      0.0    0.898     5
# Total extinctions: 0
# Generation time: 0.040 sec (0.043 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: -1302.50735 stdev: 4079.77992
# Best fitness: 0.00000 - size: (2, 1) - species 17 - id 13203
#
# Species 17 with 29 members is stagnated: removing it
# Average adjusted fitness: 0.945
# Mean genetic distance 2.046, standard deviation 0.714
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18    8    57      0.0    0.952     7
#     19    8    41      0.0    0.929     7
#     20    7    52      0.0    0.955     6
# Total extinctions: 0
# Generation time: 0.039 sec (0.042 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: -942.39037 stdev: 3471.54242
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 13352
# Average adjusted fitness: 0.941
# Mean genetic distance 2.144, standard deviation 0.667
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18    9    57      0.0    0.955     8
#     19    9    57      0.0    0.923     8
#     20    8    36      0.0    0.946     7
# Total extinctions: 0
# Generation time: 0.038 sec (0.041 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: -962.48116 stdev: 3543.21905
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 13502
# Average adjusted fitness: 0.943
# Mean genetic distance 2.030, standard deviation 0.717
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   10    39      0.0    0.952     9
#     19   10    18      0.0    0.927     9
#     20    9    93      0.0    0.949     8
# Total extinctions: 0
# Generation time: 0.038 sec (0.041 average)
#
#  ****** Running generation 91 ******
#
# Population's average fitness: -1332.66910 stdev: 4135.82582
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 13652
# Average adjusted fitness: 0.912
# Mean genetic distance 1.896, standard deviation 0.705
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   11    47      0.0    0.890    10
#     19   11    25      0.0    0.913    10
#     20   10    78      0.0    0.933     9
# Total extinctions: 0
# Generation time: 0.039 sec (0.041 average)
#
#  ****** Running generation 92 ******
#
# Population's average fitness: -1916.15096 stdev: 4949.22486
# Best fitness: 0.00000 - size: (2, 1) - species 18 - id 13802
# Average adjusted fitness: 0.907
# Mean genetic distance 2.096, standard deviation 0.709
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   12    49      0.0    0.912    11
#     19   12    44      0.0    0.914    11
#     20   11    55      0.0    0.894    10
#     21    0     3       --       --     0
# Total extinctions: 0
# Generation time: 0.040 sec (0.040 average)
#
#  ****** Running generation 93 ******
#
# Population's average fitness: -1895.88370 stdev: 4988.40857
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 13952
# Average adjusted fitness: 0.883
# Mean genetic distance 2.292, standard deviation 0.809
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   13    40      0.0    0.912    12
#     19   13    31      0.0    0.877    12
#     20   12    40      0.0    0.910    11
#     21    1    40      0.0    0.833     0
# Total extinctions: 0
# Generation time: 0.042 sec (0.040 average)
#
#  ****** Running generation 94 ******
#
# Population's average fitness: -1358.91932 stdev: 3997.66698
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 14103
# Average adjusted fitness: 0.928
# Mean genetic distance 2.262, standard deviation 0.793
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   14    31      0.0    0.923    13
#     19   14    36      0.0    0.971    13
#     20   13    56      0.0    0.892    12
#     21    2    28      0.0    0.925     1
# Total extinctions: 0
# Generation time: 0.041 sec (0.040 average)
#
#  ****** Running generation 95 ******
#
# Population's average fitness: -1143.02059 stdev: 3743.61434
# Best fitness: 0.00000 - size: (3, 2) - species 18 - id 14256
# Average adjusted fitness: 0.930
# Mean genetic distance 2.266, standard deviation 0.764
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   15    28      0.0    0.888    14
#     19   15    28      0.0    0.956    14
#     20   14    61      0.0    0.933    13
#     21    3    33      0.0    0.943     2
# Total extinctions: 0
# Generation time: 0.041 sec (0.040 average)
#
#  ****** Running generation 96 ******
#
# Population's average fitness: -837.62035 stdev: 3099.14415
# Best fitness: 0.00000 - size: (2, 1) - species 20 - id 14405
# Average adjusted fitness: 0.951
# Mean genetic distance 2.245, standard deviation 0.667
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   16    26      0.0    0.919    15
#     19   16    24      0.0    0.964    15
#     20   15    61      0.0    0.939    14
#     21    4    39      0.0    0.983     3
# Total extinctions: 0
# Generation time: 0.041 sec (0.040 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: -917.62043 stdev: 3551.60913
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 14555
# Average adjusted fitness: 0.943
# Mean genetic distance 2.178, standard deviation 0.711
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   17    18      0.0    0.924    16
#     19   17    28      0.0    0.959    16
#     20   16    70      0.0    0.956    15
#     21    5    34      0.0    0.935     4
# Total extinctions: 0
# Generation time: 0.041 sec (0.040 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: -1388.46620 stdev: 4268.24737
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 14705
# Average adjusted fitness: 0.916
# Mean genetic distance 2.123, standard deviation 0.772
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   18    32      0.0    0.881    17
#     19   18    26      0.0    0.929    17
#     20   17    57      0.0    0.902    16
#     21    6    35      0.0    0.954     5
# Total extinctions: 0
# Generation time: 0.039 sec (0.040 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: -664.18034 stdev: 2721.65972
# Best fitness: 0.00000 - size: (2, 0) - species 18 - id 14855
# Average adjusted fitness: 0.966
# Mean genetic distance 2.024, standard deviation 0.766
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     18   19    37      0.0    0.982    18
#     19   19    25      0.0    1.000    18
#     20   18    37      0.0    0.942    17
#     21    7    51      0.0    0.939     6
# Total extinctions: 0
# Generation time: 0.039 sec (0.040 average)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 70
#      68 local_dir = os.getcwd()
#      69 config_path = os.path.join(local_dir, "config-feedforward-fast.txt")
# ---> 70 run_neat(config_path)
#
# Cell In[12], line 65, in run_neat(config_file)
#      63 pygame.draw.rect(window, RED, (worm.x, worm.y, WORM_WIDTH, WORM_HEIGHT))
#      64 pygame.display.update()
# ---> 65 clock.tick(60)
#
# KeyboardInterrupt:

# %%
import pygame
import neat
import os

# %%
GRID_WIDTH = 50
GRID_HEIGHT = 50
grid = [[0 for _ in range(GRID_WIDTH)] for _ in range(GRID_HEIGHT)]

# %%
class Mosquito:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def move_left(self):
        self.x -= 1

    def move_right(self):
        self.x += 1

    def move_up(self):
        self.y -= 1

    def move_down(self):
        self.y += 1

# %%
import neat

def activate_neural_network(neural_network, inputs):
    return neural_network.activate(inputs)

# %%
def evaluate_mosquito(neural_network):
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    max_steps = GRID_WIDTH + GRID_HEIGHT  # Max steps to prevent infinite loops

    for step in range(max_steps):
        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
        output = neural_network.activate(inputs)

        # Determine the action based on the neural network's output
        if output[0] > 0.5:  # Move left
            mosquito.move_left()
        if output[1] > 0.5:  # Move right
            mosquito.move_right()
        if output[2] > 0.5:  # Move up
            mosquito.move_up()
        if output[3] > 0.5:  # Move down
            mosquito.move_down()

        # Check if the mosquito has reached the target cell
        if mosquito.x == TARGET_X and mosquito.y == TARGET_Y:
            return 1.0  # Full fitness if the mosquito reaches the target

    # If the mosquito didn't reach the target within the maximum steps, calculate partial fitness
    distance_to_target = abs(mosquito.x - TARGET_X) + abs(mosquito.y - TARGET_Y)
    return 1.0 / (1.0 + distance_to_target)  # Higher fitness for being closer to the target

def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        neural_network = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = evaluate_mosquito(neural_network)
        genome.fitness = fitness

# %%
def run_neat(config_file):
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation, config_file)

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)

    winner = population.run(eval_genomes, n=NUM_GENERATIONS)

    # Display the winning genome
    print('\nBest genome:\n{!s}'.format(winner))

    # Run the simulation with the best genome
    neural_network = neat.nn.FeedForwardNetwork.create(winner, config)
    simulate_mosquito(neural_network)

# %%
import numpy as np
import neat
import pygame
import sys


# Define colors for visualization
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Set the size of each cell in the grid
CELL_SIZE = 10

NUM_GENERATIONS = 100

# Define the target position for the mosquito
TARGET_X = 20  # You can set the desired X-coordinate of the target
TARGET_Y = 20  # You can set the desired Y-coordinate of the target

# Define the size of the grid
GRID_WIDTH = 40  # You can set the width of the grid (number of cells)
GRID_HEIGHT = 40 

class Mosquito:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def move_left(self):
        self.x -= 1

    def move_right(self):
        self.x += 1

    def move_up(self):
        self.y -= 1

    def move_down(self):
        self.y += 1




def apply_game_of_life_rules(grid):
    new_grid = np.copy(grid)
    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            # Count the number of alive neighbors for each cell
            num_alive_neighbors = np.sum(grid[max(0, y-1):min(grid.shape[0], y+2), max(0, x-1):min(grid.shape[1], x+2)]) - grid[y, x]
            if grid[y, x] == 1:
                if num_alive_neighbors < 2 or num_alive_neighbors > 3:
                    new_grid[y, x] = 0  # Cell dies due to underpopulation or overpopulation
            else:
                if num_alive_neighbors == 3:
                    new_grid[y, x] = 1  # Dead cell becomes alive due to reproduction
    return new_grid
    

def evaluate_mosquito(neural_network):
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)  # Initialize the grid
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    max_steps = GRID_WIDTH + GRID_HEIGHT  # Max steps to prevent infinite loops

    for step in range(max_steps):
        # Apply Game of Life rules to update the grid
        grid = apply_game_of_life_rules(grid)

        # Calculate inputs for the neural network
        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
        # You can also include additional information from the grid if needed

        # Get neural network output and update mosquito's position
        output = neural_network.activate(inputs)
        if output[0] > 0.5:  # Move left
            mosquito.move_left()
        if output[1] > 0.5:  # Move right
            mosquito.move_right()
        if output[2] > 0.5:  # Move up
            mosquito.move_up()
        if output[3] > 0.5:  # Move down
            mosquito.move_down()

        # Check if the mosquito has reached the target cell
        if mosquito.x == TARGET_X and mosquito.y == TARGET_Y:
            return 1.0  # Full fitness if the mosquito reaches the target

    # If the mosquito didn't reach the target within the maximum steps, calculate partial fitness
    distance_to_target = abs(mosquito.x - TARGET_X) + abs(mosquito.y - TARGET_Y)
    return 1.0 / (1.0 + distance_to_target)  # Higher fitness for being closer to the target


def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        neural_network = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = evaluate_mosquito(neural_network)
        genome.fitness = fitness



# Define colors for visualization
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Set the size of each cell in the grid
CELL_SIZE = 10

def draw_grid(screen, grid):
    screen.fill(BLACK)  # Fill the screen with a black background

    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            color = WHITE if grid[y, x] == 0 else RED
            pygame.draw.rect(screen, color, (x * CELL_SIZE, y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

    pygame.display.flip()  # Update the display

def visualize_simulation(winner):
    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    neural_network = neat.nn.FeedForwardNetwork.create(winner, config)
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)  # Initialize the grid
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)

    clock = pygame.time.Clock()
    running = True

    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

        # Apply Game of Life rules to update the grid
        grid = apply_game_of_life_rules(grid)

        # Calculate inputs for the neural network
        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
        # You can also include additional information from the grid if needed

        # Get neural network output and update mosquito's position
        output = neural_network.activate(inputs)
        if output[0] > 0.5:  # Move left
            mosquito.move_left()
        if output[1] > 0.5:  # Move right
            mosquito.move_right()
        if output[2] > 0.5:  # Move up
            mosquito.move_up()
        if output[3] > 0.5:  # Move down
            mosquito.move_down()

        # Draw the grid and mosquito
        draw_grid(screen, grid)
        pygame.draw.rect(screen, RED, (mosquito.x * CELL_SIZE, mosquito.y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

        pygame.display.flip()  # Update the display
        clock.tick(10)  # Adjust the frame rate as needed
        pygame.time.delay(100)

    pygame.quit()
    


def main():
    # Initialize NEAT configuration and run the simulation
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         'neat_config_file.txt')  # Replace 'neat_config_file.txt' with your actual config file

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)

    winner = population.run(eval_genomes, n=NUM_GENERATIONS)

    # Visualize the simulation with the winner genome
    visualize_simulation(winner)

if __name__ == "__main__":
    main()
# Out:
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.31719 stdev: 0.45220
# Best fitness: 1.00000 - size: (6, 12) - species 2 - id 2
# Average adjusted fitness: 0.311
# Mean genetic distance 3.381, standard deviation 0.500
# Population of 100 members in 50 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     2      0.0    0.000     0
#      2    0     2      1.0    0.994     0
#      3    0     2      0.0    0.006     0
#      4    0     2      0.0    0.004     0
#      5    0     2      1.0    0.994     0
#      6    0     2      0.0    0.006     0
#      7    0     2      0.0    0.003     0
#      8    0     2      0.0    0.000     0
#      9    0     2      0.0    0.004     0
#     10    0     2      1.0    0.994     0
#     11    0     2      0.0    0.006     0
#     12    0     2      0.0    0.007     0
#     13    0     2      0.0    0.003     0
#     14    0     2      0.0    0.006     0
#     15    0     2      0.0    0.006     0
#     16    0     2      0.0    0.000     0
#     17    0     2      0.0    0.027     0
#     18    0     2      0.0    0.006     0
#     19    0     2      1.0    0.994     0
#     20    0     2      0.0    0.006     0
#     21    0     2      0.0    0.006     0
#     22    0     2      1.0    0.994     0
#     23    0     2      1.0    0.994     0
#     24    0     2      0.0    0.005     0
#     25    0     2      0.0    0.006     0
#     26    0     2      1.0    0.994     0
#     27    0     2      1.0    0.994     0
#     28    0     2      0.0    0.006     0
#     29    0     2      0.0    0.000     0
#     30    0     2      1.0    0.994     0
#     31    0     2      0.0    0.000     0
#     32    0     2      0.0    0.000     0
#     33    0     2      0.0    0.006     0
#     34    0     2      1.0    0.994     0
#     35    0     2      0.0    0.000     0
#     36    0     2      1.0    0.994     0
#     37    0     2      0.0    0.000     0
#     38    0     2      1.0    0.994     0
#     39    0     2      1.0    0.994     0
#     40    0     2      1.0    0.994     0
#     41    0     2      0.0    0.006     0
#     42    0     2      0.0    0.006     0
#     43    0     2      0.0    0.000     0
#     44    0     2      0.0    0.006     0
#     45    0     2      0.5    0.494     0
#     46    0     2      0.0    0.000     0
#     47    0     2      0.0    0.001     0
#     48    0     2      0.0    0.006     0
#     49    0     2      0.0    0.003     0
#     50    0     2      1.0    0.994     0
# Total extinctions: 0
# Generation time: 16.633 sec
#
#  ****** Running generation 1 ******
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 183
#     180     visualize_simulation(winner)
#     182 if __name__ == "__main__":
# --> 183     main()
#
# Cell In[7], line 177, in main()
#     174 stats = neat.StatisticsReporter()
#     175 population.add_reporter(stats)
# --> 177 winner = population.run(eval_genomes, n=NUM_GENERATIONS)
#     179 # Visualize the simulation with the winner genome
#     180 visualize_simulation(winner)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/neat/population.py:89, in Population.run(self, fitness_function, n)
#      86 self.reporters.start_generation(self.generation)
#      88 # Evaluate all genomes using the user-provided function.
# ---> 89 fitness_function(list(iteritems(self.population)), self.config)
#      91 # Gather and report statistics.
#      92 best = None
#
# Cell In[7], line 96, in eval_genomes(genomes, config)
#      94 for genome_id, genome in genomes:
#      95     neural_network = neat.nn.FeedForwardNetwork.create(genome, config)
# ---> 96     fitness = evaluate_mosquito(neural_network)
#      97     genome.fitness = fitness
#
# Cell In[7], line 67, in evaluate_mosquito(neural_network)
#      63 max_steps = GRID_WIDTH + GRID_HEIGHT  # Max steps to prevent infinite loops
#      65 for step in range(max_steps):
#      66     # Apply Game of Life rules to update the grid
# ---> 67     grid = apply_game_of_life_rules(grid)
#      69     # Calculate inputs for the neural network
#      70     inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
#
# Cell In[7], line 50, in apply_game_of_life_rules(grid)
#      47 for y in range(grid.shape[0]):
#      48     for x in range(grid.shape[1]):
#      49         # Count the number of alive neighbors for each cell
# ---> 50         num_alive_neighbors = np.sum(grid[max(0, y-1):min(grid.shape[0], y+2), max(0, x-1):min(grid.shape[1], x+2)]) - grid[y, x]
#      51         if grid[y, x] == 1:
#      52             if num_alive_neighbors < 2 or num_alive_neighbors > 3:
#
# KeyboardInterrupt:

# %%
import numpy as np
import neat
import pygame
import sys

# Define colors for visualization
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Set the size of each cell in the grid
CELL_SIZE = 10

NUM_GENERATIONS = 100

# Define the target position for the mosquito
TARGET_X = 20  # You can set the desired X-coordinate of the target
TARGET_Y = 20  # You can set the desired Y-coordinate of the target

# Define the size of the grid
GRID_WIDTH = 40  # You can set the width of the grid (number of cells)
GRID_HEIGHT = 40

class Mosquito:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def move_left(self):
        self.x -= 1

    def move_right(self):
        self.x += 1

    def move_up(self):
        self.y -= 1

    def move_down(self):
        self.y += 1

def apply_game_of_life_rules(grid):
    new_grid = np.copy(grid)
    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            # Count the number of alive neighbors for each cell
            num_alive_neighbors = np.sum(grid[max(0, y-1):min(grid.shape[0], y+2), max(0, x-1):min(grid.shape[1], x+2)]) - grid[y, x]
            if grid[y, x] == 1:
                if num_alive_neighbors < 2 or num_alive_neighbors > 3:
                    new_grid[y, x] = 0  # Cell dies due to underpopulation or overpopulation
            else:
                if num_alive_neighbors == 3:
                    new_grid[y, x] = 1  # Dead cell becomes alive due to reproduction
    return new_grid

def evaluate_mosquito(neural_network):
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)  # Initialize the grid
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    max_steps = GRID_WIDTH + GRID_HEIGHT  # Max steps to prevent infinite loops

    for step in range(max_steps):
        # Apply Game of Life rules to update the grid
        grid = apply_game_of_life_rules(grid)

        # Calculate inputs for the neural network
        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
        # You can also include additional information from the grid if needed

        # Get neural network output and update mosquito's position
        output = neural_network.activate(inputs)
        if output[0] > 0.5:  # Move left
            mosquito.move_left()
        if output[1] > 0.5:  # Move right
            mosquito.move_right()
        if output[2] > 0.5:  # Move up
            mosquito.move_up()
        if output[3] > 0.5:  # Move down
            mosquito.move_down()

        # Check if the mosquito has reached the target cell
        if mosquito.x == TARGET_X and mosquito.y == TARGET_Y:
            return 1.0  # Full fitness if the mosquito reaches the target

    # If the mosquito didn't reach the target within the maximum steps, calculate partial fitness
    distance_to_target = abs(mosquito.x - TARGET_X) + abs(mosquito.y - TARGET_Y)
    return 1.0 / (1.0 + distance_to_target)  # Higher fitness for being closer to the target

def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        neural_network = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = evaluate_mosquito(neural_network)
        genome.fitness = fitness

def draw_grid(screen, grid):
    screen.fill(BLACK)  # Fill the screen with a black background

    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            color = WHITE if grid[y, x] == 0 else RED
            pygame.draw.rect(screen, color, (x * CELL_SIZE, y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

    pygame.display.flip()  # Update the display

def visualize_simulation(winner):
    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    neural_network = neat.nn.FeedForwardNetwork.create(winner, config)
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)  # Initialize the grid
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)

    clock = pygame.time.Clock()
    running = True

    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

        # Apply Game of Life rules to update the grid
        grid = apply_game_of_life_rules(grid)

        # Calculate inputs for the neural network
        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
        # You can also include additional information from the grid if needed

        # Get neural network output and update mosquito's position
        output = neural_network.activate(inputs)
        if output[0] > 0.5:  # Move left
            mosquito.move_left()
        if output[1] > 0.5:  # Move right
            mosquito.move_right()
        if output[2] > 0.5:  # Move up
            mosquito.move_up()
        if output[3] > 0.5:  # Move down
            mosquito.move_down()

        # Draw the grid and mosquito
        draw_grid(screen, grid)
        pygame.draw.rect(screen, RED, (mosquito.x * CELL_SIZE, mosquito.y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

        pygame.display.flip()  # Update the display
        clock.tick(10)  # Adjust the frame rate as needed
        pygame.time.delay(100)

    pygame.quit()

def main(neural_network):
    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    clock = pygame.time.Clock()
    running = True

    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

        # Apply Game of Life rules to update the grid
        grid = apply_game_of_life_rules(grid)

        # Calculate inputs for the neural network
        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
        # You can also include additional information from the grid if needed

        # Get neural network output and update mosquito's position
        output = neural_network.activate(inputs)
        if output[0] > 0.5:  # Move left
            mosquito.move_left()
        if output[1] > 0.5:  # Move right
            mosquito.move_right()
        if output[2] > 0.5:  # Move up
            mosquito.move_up()
        if output[3] > 0.5:  # Move down
            mosquito.move_down()

        # Draw the grid and mosquito
        draw_grid(screen, grid)
        pygame.draw.rect(screen, RED, (mosquito.x * CELL_SIZE, mosquito.y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

        pygame.display.flip()  # Update the display
        clock.tick(10)  # Adjust the frame rate as needed

    pygame.quit()

if __name__ == "__main__":
    # Initialize NEAT configuration and run the simulation
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         'neat_config_file.txt')  # Replace 'neat_config_file.txt' with your actual config file

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)

    winner = population.run(eval_genomes, n=NUM_GENERATIONS)

    # Visualize the simulation with the winner genome
    visualize_simulation(winner)
    main(winner)
# Out:
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.23063 stdev: 0.40869
# Best fitness: 1.00000 - size: (6, 12) - species 4 - id 4
# Average adjusted fitness: 0.224
# Mean genetic distance 3.280, standard deviation 0.488
# Population of 100 members in 50 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     2      0.0    0.000     0
#      2    0     2      0.0    0.006     0
#      3    0     2      0.0    0.000     0
#      4    0     2      1.0    0.994     0
#      5    0     2      0.0    0.035     0
#      6    0     2      0.0    0.006     0
#      7    0     2      0.0    0.006     0
#      8    0     2      0.0    0.000     0
#      9    0     2      0.0    0.006     0
#     10    0     2      0.0    0.001     0
#     11    0     2      0.0    0.006     0
#     12    0     2      0.0    0.006     0
#     13    0     2      0.0    0.041     0
#     14    0     2      0.0    0.006     0
#     15    0     2      0.0    0.002     0
#     16    0     2      0.0    0.003     0
#     17    0     2      0.0    0.000     0
#     18    0     2      1.0    0.994     0
#     19    0     2      0.0    0.006     0
#     20    0     2      0.0    0.006     0
#     21    0     2      0.0    0.000     0
#     22    0     2      0.0    0.006     0
#     23    0     2      0.0    0.006     0
#     24    0     2      0.0    0.003     0
#     25    0     2      1.0    0.994     0
#     26    0     2      1.0    0.994     0
#     27    0     2      1.0    0.994     0
#     28    0     2      1.0    0.994     0
#     29    0     2      0.0    0.006     0
#     30    0     2      0.0    0.000     0
#     31    0     2      0.0    0.007     0
#     32    0     2      0.0    0.006     0
#     33    0     2      0.0    0.003     0
#     34    0     2      1.0    0.994     0
#     35    0     2      0.1    0.044     0
#     36    0     2      0.0    0.006     0
#     37    0     2      0.0    0.006     0
#     38    0     2      0.0    0.006     0
#     39    0     2      0.0    0.006     0
#     40    0     2      0.0    0.006     0
#     41    0     2      1.0    0.994     0
#     42    0     2      0.0    0.006     0
#     43    0     2      1.0    0.994     0
#     44    0     2      0.0    0.006     0
#     45    0     2      0.0    0.012     0
#     46    0     2      0.0    0.006     0
#     47    0     2      0.0    0.003     0
#     48    0     2      1.0    0.994     0
#     49    0     2      0.0    0.006     0
#     50    0     2      1.0    0.994     0
# Total extinctions: 0
# Generation time: 18.874 sec
#
#  ****** Running generation 1 ******

# %%
import numpy as np
import neat
import pygame
import sys

# Define colors for visualization
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Set the size of each cell in the grid
CELL_SIZE = 10

NUM_GENERATIONS = 100

# Define the target position for the mosquito
TARGET_X = 20  # You can set the desired X-coordinate of the target
TARGET_Y = 20  # You can set the desired Y-coordinate of the target

# Define the size of the grid
GRID_WIDTH = 40  # You can set the width of the grid (number of cells)
GRID_HEIGHT = 40

class Mosquito:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def move_left(self):
        self.x -= 1

    def move_right(self):
        self.x += 1

    def move_up(self):
        self.y -= 1

    def move_down(self):
        self.y += 1

def apply_game_of_life_rules(grid):
    new_grid = np.copy(grid)
    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            # Count the number of alive neighbors for each cell
            num_alive_neighbors = np.sum(grid[max(0, y-1):min(grid.shape[0], y+2), max(0, x-1):min(grid.shape[1], x+2)]) - grid[y, x]
            if grid[y, x] == 1:
                if num_alive_neighbors < 2 or num_alive_neighbors > 3:
                    new_grid[y, x] = 0  # Cell dies due to underpopulation or overpopulation
            else:
                if num_alive_neighbors == 3:
                    new_grid[y, x] = 1  # Dead cell becomes alive due to reproduction
    return new_grid

def evaluate_mosquito(neural_network):
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)  # Initialize the grid
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    max_steps = GRID_WIDTH + GRID_HEIGHT  # Max steps to prevent infinite loops

    for step in range(max_steps):
        # Apply Game of Life rules to update the grid
        grid = apply_game_of_life_rules(grid)

        # Calculate inputs for the neural network
        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
        # You can also include additional information from the grid if needed

        # Get neural network output and update mosquito's position
        output = neural_network.activate(inputs)
        if output[0] > 0.5:  # Move left
            mosquito.move_left()
        if output[1] > 0.5:  # Move right
            mosquito.move_right()
        if output[2] > 0.5:  # Move up
            mosquito.move_up()
        if output[3] > 0.5:  # Move down
            mosquito.move_down()

        # Check if the mosquito has reached the target cell
        if mosquito.x == TARGET_X and mosquito.y == TARGET_Y:
            return 1.0  # Full fitness if the mosquito reaches the target

    # If the mosquito didn't reach the target within the maximum steps, calculate partial fitness
    distance_to_target = abs(mosquito.x - TARGET_X) + abs(mosquito.y - TARGET_Y)
    return 1.0 / (1.0 + distance_to_target)  # Higher fitness for being closer to the target

def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        neural_network = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = evaluate_mosquito(neural_network)
        genome.fitness = fitness

def draw_grid(screen, grid):
    screen.fill(BLACK)  # Fill the screen with a black background

    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            color = WHITE if grid[y, x] == 0 else RED
            pygame.draw.rect(screen, color, (x * CELL_SIZE, y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

    pygame.display.flip()  # Update the display

def visualize_simulation(winner):
    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    neural_network = neat.nn.FeedForwardNetwork.create(winner, config)
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)  # Initialize the grid
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)

    clock = pygame.time.Clock()
    running = True

    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

        # Apply Game of Life rules to update the grid
        grid = apply_game_of_life_rules(grid)

        # Calculate inputs for the neural network
        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
        # You can also include additional information from the grid if needed

        # Get neural network output and update mosquito's position
        output = neural_network.activate(inputs)
        if output[0] > 0.5:  # Move left
            mosquito.move_left()
        if output[1] > 0.5:  # Move right
            mosquito.move_right()
        if output[2] > 0.5:  # Move up
            mosquito.move_up()
        if output[3] > 0.5:  # Move down
            mosquito.move_down()

        # Draw the grid and mosquito
        draw_grid(screen, grid)
        pygame.draw.rect(screen, RED, (mosquito.x * CELL_SIZE, mosquito.y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

        pygame.display.flip()  # Update the display
        clock.tick(10)  # Adjust the frame rate as needed
        pygame.time.delay(100)

    pygame.quit()

def main(neural_network):
    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    clock = pygame.time.Clock()
    running = True

    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

        # Apply Game of Life rules to update the grid
        grid = apply_game_of_life_rules(grid)

        # Calculate inputs for the neural network
        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
        # You can also include additional information from the grid if needed

        # Get neural network output and update mosquito's position
        output = neural_network.activate(inputs)
        if output[0] > 0.5:  # Move left
            mosquito.move_left()
        if output[1] > 0.5:  # Move right
            mosquito.move_right()
        if output[2] > 0.5:  # Move up
            mosquito.move_up()
        if output[3] > 0.5:  # Move down
            mosquito.move_down()

        # Draw the grid and mosquito
        draw_grid(screen, grid)
        pygame.draw.rect(screen, RED, (mosquito.x * CELL_SIZE, mosquito.y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

        pygame.display.flip()  # Update the display
        clock.tick(10)  # Adjust the frame rate as needed

    pygame.quit()

if __name__ == "__main__":
    # Initialize NEAT configuration and run the simulation
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         'neat_config_file.txt')  # Replace 'neat_config_file.txt' with your actual config file

    pygame.init()  # Initialize Pygame
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)

    winner = population.run(eval_genomes, n=NUM_GENERATIONS)

    # Visualize the simulation with the winner genome
    visualize_simulation(winner)
    main(winner)
# Out:
# pygame 2.5.0 (SDL 2.28.0, Python 3.10.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.21378 stdev: 0.39458
# Best fitness: 1.00000 - size: (6, 12) - species 8 - id 8
# Average adjusted fitness: 0.208
# Mean genetic distance 3.313, standard deviation 0.504
# Population of 100 members in 50 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     2      0.0    0.000     0
#      2    0     2      0.0    0.006     0
#      3    0     2      0.0    0.006     0
#      4    0     2      0.0    0.006     0
#      5    0     2      0.0    0.004     0
#      6    0     2      0.0    0.000     0
#      7    0     2      0.0    0.006     0
#      8    0     2      1.0    0.994     0
#      9    0     2      0.0    0.006     0
#     10    0     2      0.0    0.006     0
#     11    0     2      0.0    0.000     0
#     12    0     2      0.0    0.016     0
#     13    0     2      0.0    0.006     0
#     14    0     2      0.2    0.244     0
#     15    0     2      0.0    0.000     0
#     16    0     2      0.0    0.000     0
#     17    0     2      1.0    0.994     0
#     18    0     2      0.0    0.000     0
#     19    0     2      0.0    0.000     0
#     20    0     2      0.0    0.006     0
#     21    0     2      0.0    0.006     0
#     22    0     2      0.0    0.006     0
#     23    0     2      1.0    0.994     0
#     24    0     2      0.0    0.006     0
#     25    0     2      0.0    0.001     0
#     26    0     2      0.0    0.006     0
#     27    0     2      1.0    0.994     0
#     28    0     2      1.0    0.994     0
#     29    0     2      0.0    0.000     0
#     30    0     2      1.0    0.994     0
#     31    0     2      0.0    0.000     0
#     32    0     2      0.0    0.006     0
#     33    0     2      0.0    0.006     0
#     34    0     2      0.0    0.006     0
#     35    0     2      0.0    0.000     0
#     36    0     2      0.1    0.049     0
#     37    0     2      0.0    0.006     0
#     38    0     2      0.0    0.000     0
#     39    0     2      1.0    0.994     0
#     40    0     2      0.0    0.000     0
#     41    0     2      1.0    0.994     0
#     42    0     2      0.0    0.006     0
#     43    0     2      0.0    0.006     0
#     44    0     2      0.0    0.005     0
#     45    0     2      0.0    0.000     0
#     46    0     2      1.0    0.994     0
#     47    0     2      0.0    0.006     0
#     48    0     2      1.0    0.994     0
#     49    0     2      0.0    0.000     0
#     50    0     2      0.0    0.006     0
# Total extinctions: 0
# Generation time: 19.321 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.18127 stdev: 0.37133
# Best fitness: 1.00000 - size: (6, 11) - species 2 - id 70
# Average adjusted fitness: 0.175
# Mean genetic distance 3.313, standard deviation 0.504
# Population of 100 members in 50 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     2      0.0    0.003     0
#      2    1     2      1.0    0.500     0
#      3    1     2      1.0    0.500     0
#      4    1     2      0.0    0.006     1
#      5    1     2      0.0    0.002     1
#      6    1     2      0.0    0.003     0
#      7    1     2      0.0    0.006     1
#      8    1     2      1.0    0.994     1
#      9    1     2      0.0    0.003     1
#     10    1     2      0.0    0.003     1
#     11    1     2      0.0    0.000     0
#     12    1     2      0.0    0.008     1
#     13    1     2      0.0    0.005     1
#     14    1     2      1.0    0.619     0
#     15    1     2      0.0    0.003     0
#     16    1     2      0.0    0.000     1
#     17    1     2      1.0    0.994     1
#     18    1     2      0.0    0.000     1
#     19    1     2      0.0    0.003     0
#     20    1     2      0.0    0.003     1
#     21    1     2      0.0    0.007     0
#     22    1     2      0.0    0.006     1
#     23    1     2      1.0    0.500     1
#     24    1     2      0.0    0.006     1
#     25    1     2      0.0    0.001     1
#     26    1     2      0.0    0.006     1
#     27    1     2      1.0    0.500     1
#     28    1     2      1.0    0.500     1
#     29    1     2      0.0    0.000     1
#     30    1     2      1.0    0.994     1
#     31    1     2      0.0    0.003     0
#     32    1     2      0.0    0.006     1
#     33    1     2      0.0    0.006     0
#     34    1     2      0.0    0.006     1
#     35    1     2      0.0    0.003     0
#     36    1     2      0.1    0.025     1
#     37    1     2      0.0    0.006     1
#     38    1     2      0.0    0.003     0
#     39    1     2      1.0    0.500     1
#     40    1     2      0.0    0.003     0
#     41    1     2      1.0    0.500     1
#     42    1     2      0.0    0.003     1
#     43    1     2      0.0    0.003     1
#     44    1     2      0.0    0.005     0
#     45    1     2      0.0    0.003     0
#     46    1     2      1.0    0.500     1
#     47    1     2      0.0    0.006     1
#     48    1     2      1.0    0.994     1
#     49    1     2      0.0    0.000     1
#     50    1     2      0.0    0.003     1
# Total extinctions: 0
# Generation time: 39.793 sec (29.557 average)
#
#  ****** Running generation 2 ******

# %%
import numpy as np
import neat
import pygame
import sys

BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)

CELL_SIZE = 10

NUM_GENERATIONS = 100

TARGET_X = 20
TARGET_Y = 20

GRID_WIDTH = 40
GRID_HEIGHT = 40

class Mosquito:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def move_left(self):
        self.x -= 1

    def move_right(self):
        self.x += 1

    def move_up(self):
        self.y -= 1

    def move_down(self):
        self.y += 1

def apply_game_of_life_rules(grid):
    new_grid = np.copy(grid)
    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            num_alive_neighbors = np.sum(grid[max(0, y-1):min(grid.shape[0], y+2), max(0, x-1):min(grid.shape[1], x+2)]) - grid[y, x]
            if grid[y, x] == 1:
                if num_alive_neighbors < 2 or num_alive_neighbors > 3:
                    new_grid[y, x] = 0
            else:
                if num_alive_neighbors == 3:
                    new_grid[y, x] = 1
    return new_grid

def evaluate_mosquito(neural_network):
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    max_steps = GRID_WIDTH + GRID_HEIGHT

    for step in range(max_steps):
        grid = apply_game_of_life_rules(grid)

        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]

        output = neural_network.activate(inputs)
        if output[0] > 0.5:
            mosquito.move_left()
        if output[1] > 0.5:
            mosquito.move_right()
        if output[2] > 0.5:
            mosquito.move_up()
        if output[3] > 0.5:
            mosquito.move_down()

        if mosquito.x == TARGET_X and mosquito.y == TARGET_Y:
            return 1.0

    distance_to_target = abs(mosquito.x - TARGET_X) + abs(mosquito.y - TARGET_Y)
    return 1.0 / (1.0 + distance_to_target)

def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        neural_network = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = evaluate_mosquito(neural_network)
        genome.fitness = fitness

def draw_grid(screen, grid):
    screen.fill(BLACK)

    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            color = WHITE if grid[y, x] == 0 else RED
            pygame.draw.rect(screen, color, (x * CELL_SIZE, y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

    pygame.display.flip()

def visualize_simulation(winner):
    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    neural_network = neat.nn.FeedForwardNetwork.create(winner, config)
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)

    clock = pygame.time.Clock()
    running = True

    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

        grid = apply_game_of_life_rules(grid)

        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]

        output = neural_network.activate(inputs)
        if output[0] > 0.5:
            mosquito.move_left()
        if output[1] > 0.5:
            mosquito.move_right()
        if output[2] > 0.5:
            mosquito.move_up()
        if output[3] > 0.5:
            mosquito.move_down()

        draw_grid(screen, grid)
        pygame.draw.rect(screen, RED, (mosquito.x * CELL_SIZE, mosquito.y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

        pygame.display.flip()
        clock.tick(10)
        pygame.time.delay(100)

    pygame.quit()

def main(neural_network):
    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    clock = pygame.time.Clock()
    running = True

    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

        grid = apply_game_of_life_rules(grid)

        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]

        output = neural_network.activate(inputs)
        if output[0] > 0.5:
            mosquito.move_left()
        if output[1] > 0.5:
            mosquito.move_right()
        if output[2] > 0.5:
            mosquito.move_up()
        if output[3] > 0.5:
            mosquito.move_down()

        draw_grid(screen, grid)
        pygame.draw.rect(screen, RED, (mosquito.x * CELL_SIZE, mosquito.y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

        pygame.display.flip()
        clock.tick(10)

    pygame.quit()

if __name__ == "__main__":
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         'neat_config_file.txt')

    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)

    winner = population.run(eval_genomes, n=NUM_GENERATIONS)

    visualize_simulation()
    main()
    
    #WORKING
# Out:
# pygame 2.5.0 (SDL 2.28.0, Python 3.10.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.25748 stdev: 0.41835
# Best fitness: 1.00000 - size: (6, 12) - species 9 - id 9
# Average adjusted fitness: 0.251
# Mean genetic distance 3.317, standard deviation 0.477
# Population of 100 members in 50 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     2      0.0    0.037     0
#      2    0     2      0.1    0.077     0
#      3    0     2      0.0    0.006     0
#      4    0     2      0.0    0.006     0
#      5    0     2      0.0    0.000     0
#      6    0     2      0.0    0.006     0
#      7    0     2      0.0    0.006     0
#      8    0     2      0.0    0.000     0
#      9    0     2      1.0    0.994     0
#     10    0     2      0.0    0.006     0
#     11    0     2      0.0    0.006     0
#     12    0     2      0.1    0.085     0
#     13    0     2      0.0    0.006     0
#     14    0     2      0.0    0.006     0
#     15    0     2      0.2    0.160     0
#     16    0     2      1.0    0.994     0
#     17    0     2      0.0    0.006     0
#     18    0     2      0.0    0.001     0
#     19    0     2      0.0    0.006     0
#     20    0     2      0.0    0.006     0
#     21    0     2      0.0    0.000     0
#     22    0     2      1.0    0.994     0
#     23    0     2      0.0    0.006     0
#     24    0     2      0.0    0.006     0
#     25    0     2      1.0    0.994     0
#     26    0     2      1.0    0.994     0
#     27    0     2      0.0    0.006     0
#     28    0     2      1.0    0.994     0
#     29    0     2      1.0    0.994     0
#     30    0     2      0.0    0.006     0
#     31    0     2      1.0    0.994     0
#     32    0     2      1.0    0.994     0
#     33    0     2      0.0    0.000     0
#     34    0     2      0.1    0.119     0
#     35    0     2      0.0    0.006     0
#     36    0     2      0.0    0.006     0
#     37    0     2      0.0    0.001     0
#     38    0     2      0.0    0.006     0
#     39    0     2      1.0    0.994     0
#     40    0     2      0.0    0.001     0
#     41    0     2      0.0    0.006     0
#     42    0     2      0.0    0.000     0
#     43    0     2      0.0    0.002     0
#     44    0     2      0.0    0.006     0
#     45    0     2      0.0    0.002     0
#     46    0     2      1.0    0.994     0
#     47    0     2      1.0    0.994     0
#     48    0     2      0.0    0.000     0
#     49    0     2      0.0    0.000     0
#     50    0     2      0.0    0.031     0
# Total extinctions: 0
# Generation time: 18.353 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.31255 stdev: 0.45058
# Best fitness: 1.00000 - size: (6, 10) - species 8 - id 52
# Average adjusted fitness: 0.306
# Mean genetic distance 3.317, standard deviation 0.477
# Population of 100 members in 50 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     2      0.0    0.033     1
#      2    1     2      0.1    0.042     1
#      3    1     2      0.0    0.006     1
#      4    1     2      0.0    0.003     1
#      5    1     2      0.0    0.000     1
#      6    1     2      0.0    0.006     1
#      7    1     2      0.0    0.006     1
#      8    1     2      1.0    0.497     0
#      9    1     2      1.0    0.500     1
#     10    1     2      0.0    0.006     1
#     11    1     2      0.0    0.006     1
#     12    1     2      0.1    0.045     1
#     13    1     2      0.0    0.006     1
#     14    1     2      0.0    0.006     1
#     15    1     2      1.0    0.577     0
#     16    1     2      1.0    0.994     1
#     17    1     2      1.0    0.500     0
#     18    1     2      0.0    0.003     0
#     19    1     2      0.0    0.004     1
#     20    1     2      1.0    0.500     0
#     21    1     2      0.0    0.000     1
#     22    1     2      1.0    0.500     1
#     23    1     2      0.0    0.006     1
#     24    1     2      1.0    0.500     0
#     25    1     2      1.0    0.994     1
#     26    1     2      1.0    0.994     1
#     27    1     2      0.0    0.004     1
#     28    1     2      1.0    0.994     1
#     29    1     2      1.0    0.994     1
#     30    1     2      0.0    0.006     1
#     31    1     2      1.0    0.994     1
#     32    1     2      1.0    0.994     1
#     33    1     2      0.0    0.000     1
#     34    1     2      1.0    0.556     0
#     35    1     2      0.0    0.003     1
#     36    1     2      1.0    0.500     0
#     37    1     2      0.0    0.000     1
#     38    1     2      1.0    0.500     0
#     39    1     2      1.0    0.500     1
#     40    1     2      0.0    0.001     0
#     41    1     2      0.0    0.003     1
#     42    1     2      0.0    0.003     0
#     43    1     2      0.0    0.012     0
#     44    1     2      0.0    0.006     1
#     45    1     2      1.0    0.498     0
#     46    1     2      1.0    0.994     1
#     47    1     2      1.0    0.500     1
#     48    1     2      0.0    0.000     1
#     49    1     2      0.0    0.009     0
#     50    1     2      1.0    0.512     0
# Total extinctions: 0
# Generation time: 33.456 sec (25.904 average)
#
#  ****** Running generation 2 ******
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 184
#     181 stats = neat.StatisticsReporter()
#     182 population.add_reporter(stats)
# --> 184 winner = population.run(eval_genomes, n=NUM_GENERATIONS)
#     186 visualize_simulation()
#     187 main()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/neat/population.py:89, in Population.run(self, fitness_function, n)
#      86 self.reporters.start_generation(self.generation)
#      88 # Evaluate all genomes using the user-provided function.
# ---> 89 fitness_function(list(iteritems(self.population)), self.config)
#      91 # Gather and report statistics.
#      92 best = None
#
# Cell In[1], line 79, in eval_genomes(genomes, config)
#      77 for genome_id, genome in genomes:
#      78     neural_network = neat.nn.FeedForwardNetwork.create(genome, config)
# ---> 79     fitness = evaluate_mosquito(neural_network)
#      80     genome.fitness = fitness
#
# Cell In[1], line 56, in evaluate_mosquito(neural_network)
#      53 max_steps = GRID_WIDTH + GRID_HEIGHT
#      55 for step in range(max_steps):
# ---> 56     grid = apply_game_of_life_rules(grid)
#      58     inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]
#      60     output = neural_network.activate(inputs)
#
# Cell In[1], line 41, in apply_game_of_life_rules(grid)
#      39 for y in range(grid.shape[0]):
#      40     for x in range(grid.shape[1]):
# ---> 41         num_alive_neighbors = np.sum(grid[max(0, y-1):min(grid.shape[0], y+2), max(0, x-1):min(grid.shape[1], x+2)]) - grid[y, x]
#      42         if grid[y, x] == 1:
#      43             if num_alive_neighbors < 2 or num_alive_neighbors > 3:
#
# File <__array_function__ internals>:180, in sum(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2296, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2293         return out
#    2294     return res
# -> 2296 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2297                       initial=initial, where=where)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:70, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      73     if type(obj) is not mu.ndarray:
#      74         try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:70, in <dictcomp>(.0)
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      73     if type(obj) is not mu.ndarray:
#      74         try:
#
# KeyboardInterrupt:

# %%
import numpy as np
import neat
import pygame
import sys

BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)

CELL_SIZE = 10

NUM_GENERATIONS = 100

TARGET_X = 20
TARGET_Y = 20

GRID_WIDTH = 40
GRID_HEIGHT = 40

class Mosquito:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def move_left(self):
        self.x -= 1

    def move_right(self):
        self.x += 1

    def move_up(self):
        self.y -= 1

    def move_down(self):
        self.y += 1

def apply_game_of_life_rules(grid):
    new_grid = np.copy(grid)
    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            num_alive_neighbors = np.sum(grid[max(0, y-1):min(grid.shape[0], y+2), max(0, x-1):min(grid.shape[1], x+2)]) - grid[y, x]
            if grid[y, x] == 1:
                if num_alive_neighbors < 2 or num_alive_neighbors > 3:
                    new_grid[y, x] = 0
            else:
                if num_alive_neighbors == 3:
                    new_grid[y, x] = 1
    return new_grid

def evaluate_mosquito(neural_network):
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    max_steps = GRID_WIDTH + GRID_HEIGHT

    for step in range(max_steps):
        grid = apply_game_of_life_rules(grid)

        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]

        output = neural_network.activate(inputs)
        if output[0] > 0.5:
            mosquito.move_left()
        if output[1] > 0.5:
            mosquito.move_right()
        if output[2] > 0.5:
            mosquito.move_up()
        if output[3] > 0.5:
            mosquito.move_down()

        if mosquito.x == TARGET_X and mosquito.y == TARGET_Y:
            return 1.0

        print(f"Step: {step+1}, Position: ({mosquito.x}, {mosquito.y})")

    distance_to_target = abs(mosquito.x - TARGET_X) + abs(mosquito.y - TARGET_Y)
    return 1.0 / (1.0 + distance_to_target)

def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        neural_network = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = evaluate_mosquito(neural_network)
        genome.fitness = fitness

def draw_grid(screen, grid):
    screen.fill(BLACK)

    for y in range(grid.shape[0]):
        for x in range(grid.shape[1]):
            color = WHITE if grid[y, x] == 0 else RED
            pygame.draw.rect(screen, color, (x * CELL_SIZE, y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

    pygame.display.flip()

def visualize_simulation(winner):
    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    neural_network = neat.nn.FeedForwardNetwork.create(winner, config)
    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)

    clock = pygame.time.Clock()
    running = True

    max_steps = GRID_WIDTH + GRID_HEIGHT

    for step in range(max_steps):
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

        grid = apply_game_of_life_rules(grid)

        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]

        output = neural_network.activate(inputs)
        if output[0] > 0.5:
            mosquito.move_left()
        if output[1] > 0.5:
            mosquito.move_right()
        if output[2] > 0.5:
            mosquito.move_up()
        if output[3] > 0.5:
            mosquito.move_down()

        draw_grid(screen, grid)
        pygame.draw.rect(screen, RED, (mosquito.x * CELL_SIZE, mosquito.y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

        pygame.display.flip()
        clock.tick(10)
        pygame.time.delay(100)

        print(f"Step: {step+1}, Position: ({mosquito.x}, {mosquito.y})")

    pygame.quit()

def main(neural_network):
    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    clock = pygame.time.Clock()
    running = True

    grid = np.zeros((GRID_HEIGHT, GRID_WIDTH), dtype=int)
    mosquito = Mosquito(GRID_WIDTH // 2, GRID_HEIGHT // 2)
    
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

        grid = apply_game_of_life_rules(grid)

        inputs = [(mosquito.x - TARGET_X) / GRID_WIDTH, (mosquito.y - TARGET_Y) / GRID_HEIGHT]

        output = neural_network.activate(inputs)
        if output[0] > 0.5:
            mosquito.move_left()
        if output[1] > 0.5:
            mosquito.move_right()
        if output[2] > 0.5:
            mosquito.move_up()
        if output[3] > 0.5:
            mosquito.move_down()

        draw_grid(screen, grid)
        pygame.draw.rect(screen, RED, (mosquito.x * CELL_SIZE, mosquito.y * CELL_SIZE, CELL_SIZE, CELL_SIZE))

        pygame.display.flip()
        clock.tick(10)

    pygame.quit()

if __name__ == "__main__":
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         'neat_config_file.txt')

    pygame.init()
    screen = pygame.display.set_mode((GRID_WIDTH * CELL_SIZE, GRID_HEIGHT * CELL_SIZE))
    pygame.display.set_caption('Mosquito Simulation')

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)

    winner = population.run(eval_genomes, n=NUM_GENERATIONS)

    visualize_simulation(winner)
    main(winner)
# Out:
# pygame 2.5.0 (SDL 2.28.0, Python 3.10.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
#  ****** Running generation 0 ******
#
# Step: 1, Position: (20, 19)
# Step: 2, Position: (20, 18)
# Step: 3, Position: (20, 17)
# Step: 4, Position: (20, 16)
# Step: 5, Position: (20, 15)
# Step: 6, Position: (20, 14)
# Step: 7, Position: (20, 13)
# Step: 8, Position: (20, 12)
# Step: 9, Position: (20, 11)
# Step: 10, Position: (20, 10)
# Step: 11, Position: (20, 9)
# Step: 12, Position: (20, 8)
# Step: 13, Position: (20, 7)
# Step: 14, Position: (20, 6)
# Step: 15, Position: (20, 5)
# Step: 16, Position: (20, 4)
# Step: 17, Position: (20, 3)
# Step: 18, Position: (20, 2)
# Step: 19, Position: (20, 1)
# Step: 20, Position: (20, 0)
# Step: 21, Position: (20, -1)
# Step: 22, Position: (20, -2)
# Step: 23, Position: (20, -3)
# Step: 24, Position: (20, -4)
# Step: 25, Position: (20, -5)
# Step: 26, Position: (20, -6)
# Step: 27, Position: (20, -7)
# Step: 28, Position: (20, -8)
# Step: 29, Position: (20, -9)
# Step: 30, Position: (20, -10)
# Step: 31, Position: (20, -11)
# Step: 32, Position: (20, -12)
# Step: 33, Position: (20, -13)
# Step: 34, Position: (20, -14)
# Step: 35, Position: (20, -15)
# Step: 36, Position: (20, -16)
# Step: 37, Position: (20, -17)
# Step: 38, Position: (20, -18)
# Step: 39, Position: (20, -19)
# Step: 40, Position: (20, -20)
# Step: 41, Position: (20, -21)
# Step: 42, Position: (20, -22)
# Step: 43, Position: (20, -23)
# Step: 44, Position: (20, -24)
# Step: 45, Position: (20, -25)
# Step: 46, Position: (20, -26)
# Step: 47, Position: (19, -27)
# Step: 48, Position: (18, -28)
# Step: 49, Position: (17, -29)
# Step: 50, Position: (16, -30)
